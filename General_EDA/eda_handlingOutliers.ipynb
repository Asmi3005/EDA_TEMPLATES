# %%
import numpy as np

# %%
marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
iqr=Q3-Q1
iqr
# Out:
# 35.0

# %%
lb=Q1-1.5*iqr
lb
# Out:
# 1.5

# %%
hb=Q3+1.5*iqr
hb
# Out:
# 141.5

# %%
import seaborn as sns

# %%
sns.boxplot(marks)
# Out:
# <Axes: >

# %%
marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170]

# %%
sns.boxplot(marks)
# Out:
# <Axes: >
